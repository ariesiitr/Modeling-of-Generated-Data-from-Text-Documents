# %% [markdown]
# #Compulsary Block

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Datasets/DataModelling-master.zip
# Out:
# Archive:  /content/drive/MyDrive/Datasets/DataModelling-master.zip
# ba46350e35e0ea500a6b29c3d0554bb8d5a4ef2d
#    creating: DataModelling-master/
#    creating: DataModelling-master/.ipynb_checkpoints/
#   inflating: DataModelling-master/.ipynb_checkpoints/GAN_DataModelling-checkpoint.ipynb
#   inflating: DataModelling-master/20newsgroups.vocab
#    creating: DataModelling-master/Dataset_final/
#   inflating: DataModelling-master/Dataset_final/labels.txt
#   inflating: DataModelling-master/Dataset_final/test.csv
#   inflating: DataModelling-master/Dataset_final/training.csv
#   inflating: DataModelling-master/Dataset_final/validation.csv
#   inflating: DataModelling-master/GAN_DataModelling.ipynb
#   inflating: DataModelling-master/LICENSE
#   inflating: DataModelling-master/Notebook.ipynb
#  extracting: DataModelling-master/Readme.md
#    creating: DataModelling-master/Trainedmodels/
#   inflating: DataModelling-master/Trainedmodels/checkpoint
# ...

# %% [markdown]
# # Data Preprocessing

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python preprocess.py --input different_label_dataset --output Dataset_final_2 --vocab 20newsgroups.vocab
# Out:
# collection= validation <_io.TextIOWrapper name='Dataset_final_2/validation.csv' mode='w' encoding='UTF-8'>
# collection= test <_io.TextIOWrapper name='Dataset_final_2/test.csv' mode='w' encoding='UTF-8'>
# collection= training <_io.TextIOWrapper name='Dataset_final_2/training.csv' mode='w' encoding='UTF-8'>

# %% [markdown]
# # Training

# %%
cd /content/DataModelling-master
# Out:
# /content/DataModelling-master

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# training

# %%
pip install tf_slim
# Out:
# ...
#      |████████████████████████████████| 352 kB 12.4 MB/s
# ...

# %%
import pandas as pd
dd = pd.read_csv('dataset_2/test.csv')
testdf = dd.sample(frac = 0.5)
rest_part_50 = dd.drop(testdf.index)
testdf.to_csv('test.csv')
rest_part_50.to_csv('validation.csv')

# %%
# !python train.py --dataset Dataset_final_2 --model Trainedmodels2 --num-steps 100000 --save-every 1000
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# training label failed 9086
# validation label failed 1124
# 0: 95.385345	1019.735352
# 100: 82.709633	599.688110
# 200: 51.597198	347.080597
# 300: 54.436787	208.376236
# 400: 47.226368	117.343483
# 500: 45.615219	104.671547
# 600: 44.599052	102.357040
# 700: 49.337334	103.152161
# 800: 50.398426	104.367950
# 900: 64.492592	94.704910
# 1000: 245.678284	62.104671
# batch iteration stopped by stopiteration
# batch iteration stopped by stopiteration
# validation: 0.189 (best: 0.000)
# saving: Trainedmodels2/model
# 1100: 156.311996	22.381191
# 1200: 136.825775	11.743041
# 1300: 153.144577	6.951686
# 1400: 139.298309	5.225870
# 1500: 145.227936	4.506060
# ...

# %% [markdown]
# # Validation

# %%
# !python evaluate.py --dataset Dataset_final_2 --model Trainedmodels2
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# computing vectors...
# training label incomplete 9086
# validation label incomplete 1124
# test label incomplete 1135
# batch iteration stopped by stopiteration
# batch iteration stopped by stopiteration
# batch iteration stopped by stopiteration
# evaluating...
# precision @ 0.0001: 0.5700440528634361
# precision @ 0.0002: 0.5321585903083701
# precision @ 0.0005: 0.4949779735682817
# precision @ 0.002: 0.4229955947136566
# precision @ 0.01: 0.3412369353027559
# precision @ 0.05: 0.2248782296093838
# precision @ 0.2: 0.12009173005647918
